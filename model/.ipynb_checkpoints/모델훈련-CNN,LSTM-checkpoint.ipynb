# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# CSV 파일로부터 데이터 로드
fist_data = pd.read_csv('fist_data.csv')
open_data = pd.read_csv('open_data.csv')

# 데이터와 라벨 생성
X = pd.concat([fist_data, open_data], ignore_index=True)
y = ['fist'] * len(fist_data) + ['open'] * len(open_data)

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 데이터를 3D 형태로 변환 (samples, timesteps, features)
X = np.array(X)
X = X.reshape((X.shape[0], 1, X.shape[1]))

# 데이터를 훈련셋과 테스트셋으로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# 모델 정의
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(50),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 조기 종료 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련 (에폭과 배치사이즈 설정 가능)
epochs = 50
batch_size = 32

history = model.fit(X_train, y_train, 
                    epochs=epochs, 
                    batch_size=batch_size, 
                    validation_split=0.2, 
                    callbacks=[early_stopping],
                    verbose=1)

# 모델 저장
model.save('fist_open_model.h5')

# 테스트 데이터로 모델 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"테스트 정확도: {test_accuracy:.2f}")
# Out:
# Epoch 1/50
# C:\Users\kimha\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6118 - loss: 0.6897 - val_accuracy: 0.5789 - val_loss: 0.6882
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6067 - loss: 0.6859 - val_accuracy: 0.5789 - val_loss: 0.6850
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5728 - loss: 0.6841 - val_accuracy: 0.5789 - val_loss: 0.6813
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6510 - loss: 0.6700 - val_accuracy: 0.5789 - val_loss: 0.6767
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6136 - loss: 0.6722 - val_accuracy: 0.5789 - val_loss: 0.6716
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6080 - loss: 0.6624 - val_accuracy: 0.5789 - val_loss: 0.6649
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5767 - loss: 0.6596 - val_accuracy: 0.5789 - val_loss: 0.6560
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6002 - loss: 0.6474 - val_accuracy: 0.5789 - val_loss: 0.6440
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6419 - loss: 0.6200 - val_accuracy: 0.5789 - val_loss: 0.6291
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6137 - loss: 0.6221 - val_accuracy: 0.6316 - val_loss: 0.6069
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6387 - loss: 0.5880 - val_accuracy: 0.6842 - val_loss: 0.5791
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7077 - loss: 0.5513 - val_accuracy: 0.8421 - val_loss: 0.5441
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7322 - loss: 0.5267 - val_accuracy: 0.8684 - val_loss: 0.5019
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8762 - loss: 0.4899 - val_accuracy: 0.8947 - val_loss: 0.4508
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8731 - loss: 0.4369 - val_accuracy: 0.9474 - val_loss: 0.3936
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9098 - loss: 0.3819 - val_accuracy: 1.0000 - val_loss: 0.3324
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9260 - loss: 0.3367 - val_accuracy: 1.0000 - val_loss: 0.2726
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9021 - loss: 0.3007 - val_accuracy: 1.0000 - val_loss: 0.2169
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9498 - loss: 0.2497 - val_accuracy: 1.0000 - val_loss: 0.1675
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9610 - loss: 0.1899 - val_accuracy: 1.0000 - val_loss: 0.1260
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9716 - loss: 0.1712 - val_accuracy: 1.0000 - val_loss: 0.0930
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9606 - loss: 0.1492 - val_accuracy: 1.0000 - val_loss: 0.0718
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9585 - loss: 0.1304 - val_accuracy: 1.0000 - val_loss: 0.0539
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9625 - loss: 0.1063 - val_accuracy: 1.0000 - val_loss: 0.0418
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9739 - loss: 0.1230 - val_accuracy: 1.0000 - val_loss: 0.0364
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9899 - loss: 0.0690 - val_accuracy: 1.0000 - val_loss: 0.0271
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9791 - loss: 0.0652 - val_accuracy: 1.0000 - val_loss: 0.0243
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9869 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9869 - loss: 0.0424 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9791 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9921 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9869 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9869 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9869 - loss: 0.0310 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9947 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9869 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9921 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9869 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9965 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0024
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0090
# 테스트 정확도: 1.00
